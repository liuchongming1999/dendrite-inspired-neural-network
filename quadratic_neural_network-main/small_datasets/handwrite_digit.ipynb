# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import torch.backends.cudnn as cudnn
from tensorboardX import SummaryWriter
import model.simplenet as simplenet
import matplotlib.pyplot as plt
import torch.utils.data as Data
import imageio
import numpy as np
import random
import pandas as pd

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.enabled = False
    torch.backends.cudnn.benchmark = False
    #torch.backends.cudnn.benchmark = True #for accelerating the running
    return

def savefig(name):
    plt.savefig(name,dpi=600, bbox_inches='tight')
    return

def change_weight(weight):
    '''
    Change the weight matrix in quadratic neural network.
    '''
    model_dict = model.state_dict()
    model_dict['classifier.0.weight_a'] = weight
    model.load_state_dict(model_dict)
    
    return


from sklearn.datasets import load_digits


digits = load_digits()['data']
target = torch.from_numpy(load_digits()['target'])

for i in range(digits.shape[0]):
    digits[i,:] = digits[i,:]/max(digits[i,:])

device = torch.device('cpu')
writer = SummaryWriter()

train_dataset = torch.from_numpy(digits)
valid_dataset = torch.from_numpy(digits)


EI_distribution = torch.bernoulli(torch.ones(64)*0.75)
print('number of excitatory neuron:{}'.format(EI_distribution.sum()))
kappa_matrix = -torch.ones(64, 64)
kappa_matrix[EI_distribution==0,:] = 1
kappa_matrix[:,EI_distribution==0] = 1

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=1797, shuffle=False)
valid_loader = torch.utils.data.DataLoader(dataset=valid_dataset, batch_size=1797)


model = simplenet.SimpleNet_0(num_eigens=5,EI_distribution=EI_distribution)

print(model)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)
test_accuracy = []
train_accuracy = [0]
all_train_loss = []
image_list = []
best_prec = 0
min_loss = 1

for epoch in range(0, 10000):

    for param_group in optimizer.param_groups:
        param_group['lr'] = 0.01

    model.train()
    # train for one epoch
    for i, input in enumerate(train_loader):
        train_total = 0
        train_correct = 0
        train_loss = 0
                    
        
        # compute output
        output = model(input.to(torch.float32))
        loss = criterion(output, target)

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward() 
        optimizer.step()

        weight_a = model.state_dict()['classifier.0.weight_a']
        new_weight = weight_a.data
        for j in range(10):
            new_weight[j,(new_weight[j,:,:]*kappa_matrix)<0] = 0

        change_weight(new_weight)  

        _, predicted = torch.max(output.data, 1)
        train_total += target.size(0)
        train_correct += (predicted == target).sum().item()
        prec = train_correct / train_total

        train_accuracy.append(prec)
        all_train_loss.append(loss)

        print('Epoch [{}/{}], Step [{}/{}], Loss: {:.5f}, Train_Acc:{:.2f}%'.format(epoch+1, 10000, i, len(train_loader), loss, prec*100))


        model.eval()
        valid_correct = 0
        valid_total = 0
        with torch.no_grad():
            total_loss = 0
            for j, input in enumerate(valid_loader):
                output = model(input.to(torch.float32))
                
                _, predicted = torch.max(output.data, 1)
                valid_total = output.shape[0]
                valid_correct = (predicted == target).sum().item()
                loss = criterion(output, target)
            
                prec = valid_correct / valid_total
                print('Accuary on test images:{:.2f}%, loss:{:.2f}'.format(prec*100, loss))
                test_accuracy.append(prec)
                best_prec = max(prec, best_prec)
                min_loss = min(min_loss, loss)
        
print('Best accuracy is: {:.2f}%, Minimum loss is: {:.4f}'.format(best_prec*100, min_loss))
# Out:
# number of excitatory neuron:48.0
# SimpleNet_0(
#   (classifier): Sequential(
#     (0): Dales_General_quadratic(in_features=64, out_features=10, bias=False)
#   )
# )
# Epoch [1/10000], Step [0/1], Loss: 2.44621, Train_Acc:12.85%
# Accuary on test images:13.58%, loss:2.39
# Epoch [2/10000], Step [0/1], Loss: 2.39482, Train_Acc:13.58%
# Accuary on test images:14.91%, loss:2.35
# Epoch [3/10000], Step [0/1], Loss: 2.34586, Train_Acc:14.91%
# Accuary on test images:16.69%, loss:2.30
# Epoch [4/10000], Step [0/1], Loss: 2.29905, Train_Acc:16.69%
# Accuary on test images:18.48%, loss:2.25
# Epoch [5/10000], Step [0/1], Loss: 2.25403, Train_Acc:18.48%
# Accuary on test images:20.98%, loss:2.21
# Epoch [6/10000], Step [0/1], Loss: 2.21067, Train_Acc:20.98%
# Accuary on test images:23.82%, loss:2.17
# Epoch [7/10000], Step [0/1], Loss: 2.16881, Train_Acc:23.82%
# Accuary on test images:27.66%, loss:2.13
# Epoch [8/10000], Step [0/1], Loss: 2.12826, Train_Acc:27.66%
# Accuary on test images:30.94%, loss:2.09
# Epoch [9/10000], Step [0/1], Loss: 2.08885, Train_Acc:30.94%
# Accuary on test images:35.23%, loss:2.05
# Epoch [10/10000], Step [0/1], Loss: 2.05061, Train_Acc:35.23%
# Accuary on test images:39.12%, loss:2.01
# Epoch [11/10000], Step [0/1], Loss: 2.01341, Train_Acc:39.12%
# Accuary on test images:42.57%, loss:1.98
# Epoch [12/10000], Step [0/1], Loss: 1.97718, Train_Acc:42.57%
# Accuary on test images:45.30%, loss:1.94
# Epoch [13/10000], Step [0/1], Loss: 1.94191, Train_Acc:45.30%
# Accuary on test images:48.91%, loss:1.91
# Epoch [14/10000], Step [0/1], Loss: 1.90753, Train_Acc:48.91%
# Accuary on test images:51.53%, loss:1.87
# Epoch [15/10000], Step [0/1], Loss: 1.87408, Train_Acc:51.53%
# Accuary on test images:53.76%, loss:1.84
# Epoch [16/10000], Step [0/1], Loss: 1.84150, Train_Acc:53.76%
# Accuary on test images:55.48%, loss:1.81
# Epoch [17/10000], Step [0/1], Loss: 1.80972, Train_Acc:55.48%
# Accuary on test images:58.26%, loss:1.78
# Epoch [18/10000], Step [0/1], Loss: 1.77875, Train_Acc:58.26%
# Accuary on test images:61.16%, loss:1.75
# Epoch [19/10000], Step [0/1], Loss: 1.74859, Train_Acc:61.16%
# Accuary on test images:63.11%, loss:1.72
# Epoch [20/10000], Step [0/1], Loss: 1.71922, Train_Acc:63.11%
# Accuary on test images:64.77%, loss:1.69
# Epoch [21/10000], Step [0/1], Loss: 1.69061, Train_Acc:64.77%
# Accuary on test images:66.44%, loss:1.66
# Epoch [22/10000], Step [0/1], Loss: 1.66280, Train_Acc:66.44%
# Accuary on test images:67.67%, loss:1.64
# Epoch [23/10000], Step [0/1], Loss: 1.63573, Train_Acc:67.67%
# Accuary on test images:68.95%, loss:1.61
# Epoch [24/10000], Step [0/1], Loss: 1.60939, Train_Acc:68.95%
# Accuary on test images:70.45%, loss:1.58
# Epoch [25/10000], Step [0/1], Loss: 1.58375, Train_Acc:70.45%
# Accuary on test images:71.17%, loss:1.56
# Epoch [26/10000], Step [0/1], Loss: 1.55878, Train_Acc:71.17%
# Accuary on test images:72.01%, loss:1.53
# Epoch [27/10000], Step [0/1], Loss: 1.53445, Train_Acc:72.01%
# Accuary on test images:73.23%, loss:1.51
# Epoch [28/10000], Step [0/1], Loss: 1.51081, Train_Acc:73.23%
# Accuary on test images:74.12%, loss:1.49
# Epoch [29/10000], Step [0/1], Loss: 1.48779, Train_Acc:74.12%
# Accuary on test images:74.90%, loss:1.47
# Epoch [30/10000], Step [0/1], Loss: 1.46537, Train_Acc:74.90%
# Accuary on test images:75.85%, loss:1.44
# Epoch [31/10000], Step [0/1], Loss: 1.44351, Train_Acc:75.85%
# Accuary on test images:76.63%, loss:1.42
# Epoch [32/10000], Step [0/1], Loss: 1.42222, Train_Acc:76.63%
# Accuary on test images:77.24%, loss:1.40
# Epoch [33/10000], Step [0/1], Loss: 1.40146, Train_Acc:77.24%
# Accuary on test images:78.07%, loss:1.38
# Epoch [34/10000], Step [0/1], Loss: 1.38123, Train_Acc:78.07%
# Accuary on test images:78.41%, loss:1.36
# Epoch [35/10000], Step [0/1], Loss: 1.36150, Train_Acc:78.41%
# Accuary on test images:78.80%, loss:1.34
# Epoch [36/10000], Step [0/1], Loss: 1.34229, Train_Acc:78.80%
# Accuary on test images:79.35%, loss:1.32
# Epoch [37/10000], Step [0/1], Loss: 1.32360, Train_Acc:79.35%
# Accuary on test images:79.97%, loss:1.31
# Epoch [38/10000], Step [0/1], Loss: 1.30537, Train_Acc:79.97%
# Accuary on test images:80.52%, loss:1.29
# Epoch [39/10000], Step [0/1], Loss: 1.28760, Train_Acc:80.52%
# Accuary on test images:81.08%, loss:1.27
# Epoch [40/10000], Step [0/1], Loss: 1.27029, Train_Acc:81.08%
# Accuary on test images:81.41%, loss:1.25
# Epoch [41/10000], Step [0/1], Loss: 1.25344, Train_Acc:81.41%
# Accuary on test images:81.86%, loss:1.24
# Epoch [42/10000], Step [0/1], Loss: 1.23703, Train_Acc:81.86%
# Accuary on test images:82.64%, loss:1.22
# Epoch [43/10000], Step [0/1], Loss: 1.22104, Train_Acc:82.64%
# Accuary on test images:82.97%, loss:1.21
# Epoch [44/10000], Step [0/1], Loss: 1.20543, Train_Acc:82.97%
# Accuary on test images:83.47%, loss:1.19
# Epoch [45/10000], Step [0/1], Loss: 1.19020, Train_Acc:83.47%
# Accuary on test images:83.75%, loss:1.18
# Epoch [46/10000], Step [0/1], Loss: 1.17535, Train_Acc:83.75%
# Accuary on test images:83.92%, loss:1.16
# Epoch [47/10000], Step [0/1], Loss: 1.16087, Train_Acc:83.92%
# Accuary on test images:84.36%, loss:1.15
# Epoch [48/10000], Step [0/1], Loss: 1.14674, Train_Acc:84.36%
# Accuary on test images:84.53%, loss:1.13
# Epoch [49/10000], Step [0/1], Loss: 1.13294, Train_Acc:84.53%
# Accuary on test images:84.75%, loss:1.12
# Epoch [50/10000], Step [0/1], Loss: 1.11947, Train_Acc:84.75%
# Accuary on test images:85.25%, loss:1.11
# Epoch [51/10000], Step [0/1], Loss: 1.10631, Train_Acc:85.25%
# Accuary on test images:85.59%, loss:1.09
# Epoch [52/10000], Step [0/1], Loss: 1.09347, Train_Acc:85.59%
# Accuary on test images:85.87%, loss:1.08
# Epoch [53/10000], Step [0/1], Loss: 1.08092, Train_Acc:85.87%
# Accuary on test images:85.92%, loss:1.07
# Epoch [54/10000], Step [0/1], Loss: 1.06865, Train_Acc:85.92%
# Accuary on test images:86.03%, loss:1.06
# Epoch [55/10000], Step [0/1], Loss: 1.05667, Train_Acc:86.03%
# Accuary on test images:86.31%, loss:1.04
# Epoch [56/10000], Step [0/1], Loss: 1.04497, Train_Acc:86.31%
# Accuary on test images:86.59%, loss:1.03
# Epoch [57/10000], Step [0/1], Loss: 1.03354, Train_Acc:86.59%
# Accuary on test images:86.81%, loss:1.02
# Epoch [58/10000], Step [0/1], Loss: 1.02237, Train_Acc:86.81%
# Accuary on test images:86.92%, loss:1.01
# Epoch [59/10000], Step [0/1], Loss: 1.01145, Train_Acc:86.92%
# Accuary on test images:87.15%, loss:1.00
# Epoch [60/10000], Step [0/1], Loss: 1.00078, Train_Acc:87.15%
# Accuary on test images:87.37%, loss:0.99
# Epoch [61/10000], Step [0/1], Loss: 0.99035, Train_Acc:87.37%
# Accuary on test images:87.53%, loss:0.98
# Epoch [62/10000], Step [0/1], Loss: 0.98015, Train_Acc:87.53%
# Accuary on test images:87.65%, loss:0.97
# Epoch [63/10000], Step [0/1], Loss: 0.97017, Train_Acc:87.65%
# Accuary on test images:87.81%, loss:0.96
# Epoch [64/10000], Step [0/1], Loss: 0.96041, Train_Acc:87.81%
# Accuary on test images:87.98%, loss:0.95
# Epoch [65/10000], Step [0/1], Loss: 0.95088, Train_Acc:87.98%
# Accuary on test images:88.15%, loss:0.94
# Epoch [66/10000], Step [0/1], Loss: 0.94155, Train_Acc:88.15%
# Accuary on test images:88.20%, loss:0.93
# Epoch [67/10000], Step [0/1], Loss: 0.93242, Train_Acc:88.20%
# Accuary on test images:88.31%, loss:0.92
# Epoch [68/10000], Step [0/1], Loss: 0.92349, Train_Acc:88.31%
# Accuary on test images:88.31%, loss:0.91
# Epoch [69/10000], Step [0/1], Loss: 0.91473, Train_Acc:88.31%
# Accuary on test images:88.43%, loss:0.91
# Epoch [70/10000], Step [0/1], Loss: 0.90616, Train_Acc:88.43%
# Accuary on test images:88.48%, loss:0.90
# Epoch [71/10000], Step [0/1], Loss: 0.89776, Train_Acc:88.48%
# Accuary on test images:88.81%, loss:0.89
# Epoch [72/10000], Step [0/1], Loss: 0.88954, Train_Acc:88.81%
# Accuary on test images:89.04%, loss:0.88
# Epoch [73/10000], Step [0/1], Loss: 0.88150, Train_Acc:89.04%
# Accuary on test images:89.09%, loss:0.87
# Epoch [74/10000], Step [0/1], Loss: 0.87363, Train_Acc:89.09%
# Accuary on test images:89.26%, loss:0.87
# Epoch [75/10000], Step [0/1], Loss: 0.86593, Train_Acc:89.26%
# Accuary on test images:89.37%, loss:0.86
# Epoch [76/10000], Step [0/1], Loss: 0.85839, Train_Acc:89.37%
# Accuary on test images:89.48%, loss:0.85
# Epoch [77/10000], Step [0/1], Loss: 0.85101, Train_Acc:89.48%
# Accuary on test images:89.65%, loss:0.84
# Epoch [78/10000], Step [0/1], Loss: 0.84377, Train_Acc:89.65%
# Accuary on test images:89.82%, loss:0.84
# Epoch [79/10000], Step [0/1], Loss: 0.83667, Train_Acc:89.82%
# Accuary on test images:89.93%, loss:0.83
# Epoch [80/10000], Step [0/1], Loss: 0.82972, Train_Acc:89.93%
# Accuary on test images:89.87%, loss:0.82
# Epoch [81/10000], Step [0/1], Loss: 0.82289, Train_Acc:89.87%
# Accuary on test images:89.93%, loss:0.82
# Epoch [82/10000], Step [0/1], Loss: 0.81620, Train_Acc:89.93%
# Accuary on test images:90.04%, loss:0.81
# Epoch [83/10000], Step [0/1], Loss: 0.80964, Train_Acc:90.04%
# Accuary on test images:90.15%, loss:0.80
# Epoch [84/10000], Step [0/1], Loss: 0.80320, Train_Acc:90.15%
# Accuary on test images:90.21%, loss:0.80
# Epoch [85/10000], Step [0/1], Loss: 0.79688, Train_Acc:90.21%
# Accuary on test images:90.21%, loss:0.79
# Epoch [86/10000], Step [0/1], Loss: 0.79069, Train_Acc:90.21%
# Accuary on test images:90.21%, loss:0.78
# Epoch [87/10000], Step [0/1], Loss: 0.78460, Train_Acc:90.21%
# Accuary on test images:90.26%, loss:0.78
# Epoch [88/10000], Step [0/1], Loss: 0.77863, Train_Acc:90.26%
# Accuary on test images:90.37%, loss:0.77
# Epoch [89/10000], Step [0/1], Loss: 0.77275, Train_Acc:90.37%
# Accuary on test images:90.48%, loss:0.77
# Epoch [90/10000], Step [0/1], Loss: 0.76699, Train_Acc:90.48%
# Accuary on test images:90.65%, loss:0.76
# Epoch [91/10000], Step [0/1], Loss: 0.76132, Train_Acc:90.65%
# Accuary on test images:90.65%, loss:0.76
# Epoch [92/10000], Step [0/1], Loss: 0.75576, Train_Acc:90.65%
# Accuary on test images:90.76%, loss:0.75
# Epoch [93/10000], Step [0/1], Loss: 0.75029, Train_Acc:90.76%
# Accuary on test images:90.76%, loss:0.74
# Epoch [94/10000], Step [0/1], Loss: 0.74492, Train_Acc:90.76%
# Accuary on test images:90.76%, loss:0.74
# Epoch [95/10000], Step [0/1], Loss: 0.73964, Train_Acc:90.76%
# Accuary on test images:90.76%, loss:0.73
# Epoch [96/10000], Step [0/1], Loss: 0.73445, Train_Acc:90.76%
# Accuary on test images:90.93%, loss:0.73
# Epoch [97/10000], Step [0/1], Loss: 0.72936, Train_Acc:90.93%
# Accuary on test images:91.10%, loss:0.72
# Epoch [98/10000], Step [0/1], Loss: 0.72434, Train_Acc:91.10%
# Accuary on test images:91.15%, loss:0.72
# Epoch [99/10000], Step [0/1], Loss: 0.71941, Train_Acc:91.15%
# Accuary on test images:91.15%, loss:0.71
# Epoch [100/10000], Step [0/1], Loss: 0.71456, Train_Acc:91.15%
# Accuary on test images:91.26%, loss:0.71
# Epoch [101/10000], Step [0/1], Loss: 0.70979, Train_Acc:91.26%
# Accuary on test images:91.37%, loss:0.71
# Epoch [102/10000], Step [0/1], Loss: 0.70509, Train_Acc:91.37%
# Accuary on test images:91.37%, loss:0.70
# Epoch [103/10000], Step [0/1], Loss: 0.70047, Train_Acc:91.37%
# Accuary on test images:91.37%, loss:0.70
# Epoch [104/10000], Step [0/1], Loss: 0.69592, Train_Acc:91.37%
# Accuary on test images:91.49%, loss:0.69
# Epoch [105/10000], Step [0/1], Loss: 0.69145, Train_Acc:91.49%
# Accuary on test images:91.54%, loss:0.69
# Epoch [106/10000], Step [0/1], Loss: 0.68705, Train_Acc:91.54%
# Accuary on test images:91.60%, loss:0.68
# Epoch [107/10000], Step [0/1], Loss: 0.68272, Train_Acc:91.60%
# Accuary on test images:91.60%, loss:0.68
# Epoch [108/10000], Step [0/1], Loss: 0.67846, Train_Acc:91.60%
# Accuary on test images:91.60%, loss:0.67
# Epoch [109/10000], Step [0/1], Loss: 0.67427, Train_Acc:91.60%
# Accuary on test images:91.65%, loss:0.67
# Epoch [110/10000], Step [0/1], Loss: 0.67014, Train_Acc:91.65%
# Accuary on test images:91.65%, loss:0.67
# Epoch [111/10000], Step [0/1], Loss: 0.66607, Train_Acc:91.65%
# Accuary on test images:91.71%, loss:0.66
# Epoch [112/10000], Step [0/1], Loss: 0.66207, Train_Acc:91.71%
# Accuary on test images:91.82%, loss:0.66
# Epoch [113/10000], Step [0/1], Loss: 0.65812, Train_Acc:91.82%
# Accuary on test images:91.82%, loss:0.65
# Epoch [114/10000], Step [0/1], Loss: 0.65423, Train_Acc:91.82%
# Accuary on test images:91.88%, loss:0.65
# Epoch [115/10000], Step [0/1], Loss: 0.65041, Train_Acc:91.88%
# Accuary on test images:91.93%, loss:0.65
# Epoch [116/10000], Step [0/1], Loss: 0.64664, Train_Acc:91.93%
# Accuary on test images:91.93%, loss:0.64
# Epoch [117/10000], Step [0/1], Loss: 0.64293, Train_Acc:91.93%
# Accuary on test images:92.04%, loss:0.64
# Epoch [118/10000], Step [0/1], Loss: 0.63927, Train_Acc:92.04%
# Accuary on test images:92.10%, loss:0.64
# Epoch [119/10000], Step [0/1], Loss: 0.63565, Train_Acc:92.10%
# Accuary on test images:92.10%, loss:0.63
# Epoch [120/10000], Step [0/1], Loss: 0.63210, Train_Acc:92.10%
# Accuary on test images:92.10%, loss:0.63
# Epoch [121/10000], Step [0/1], Loss: 0.62860, Train_Acc:92.10%
# Accuary on test images:92.15%, loss:0.63
# Epoch [122/10000], Step [0/1], Loss: 0.62515, Train_Acc:92.15%
# Accuary on test images:92.26%, loss:0.62
# Epoch [123/10000], Step [0/1], Loss: 0.62175, Train_Acc:92.26%
# Accuary on test images:92.32%, loss:0.62
# Epoch [124/10000], Step [0/1], Loss: 0.61840, Train_Acc:92.32%
# Accuary on test images:92.32%, loss:0.62
# Epoch [125/10000], Step [0/1], Loss: 0.61509, Train_Acc:92.32%
# Accuary on test images:92.32%, loss:0.61
# Epoch [126/10000], Step [0/1], Loss: 0.61182, Train_Acc:92.32%
# Accuary on test images:92.32%, loss:0.61
# Epoch [127/10000], Step [0/1], Loss: 0.60860, Train_Acc:92.32%
# Accuary on test images:92.38%, loss:0.61
# Epoch [128/10000], Step [0/1], Loss: 0.60543, Train_Acc:92.38%
# Accuary on test images:92.43%, loss:0.60
# Epoch [129/10000], Step [0/1], Loss: 0.60229, Train_Acc:92.43%
# Accuary on test images:92.43%, loss:0.60
# Epoch [130/10000], Step [0/1], Loss: 0.59920, Train_Acc:92.43%
# Accuary on test images:92.43%, loss:0.60
# Epoch [131/10000], Step [0/1], Loss: 0.59614, Train_Acc:92.43%
# Accuary on test images:92.43%, loss:0.59
# Epoch [132/10000], Step [0/1], Loss: 0.59313, Train_Acc:92.43%
# Accuary on test images:92.43%, loss:0.59
# Epoch [133/10000], Step [0/1], Loss: 0.59016, Train_Acc:92.43%
# Accuary on test images:92.43%, loss:0.59
# Epoch [134/10000], Step [0/1], Loss: 0.58723, Train_Acc:92.43%
# Accuary on test images:92.49%, loss:0.58
# Epoch [135/10000], Step [0/1], Loss: 0.58434, Train_Acc:92.49%
# Accuary on test images:92.54%, loss:0.58
# Epoch [136/10000], Step [0/1], Loss: 0.58149, Train_Acc:92.54%
# Accuary on test images:92.54%, loss:0.58
# Epoch [137/10000], Step [0/1], Loss: 0.57867, Train_Acc:92.54%
# Accuary on test images:92.54%, loss:0.58
# Epoch [138/10000], Step [0/1], Loss: 0.57590, Train_Acc:92.54%
# Accuary on test images:92.54%, loss:0.57
# Epoch [139/10000], Step [0/1], Loss: 0.57316, Train_Acc:92.54%
# Accuary on test images:92.54%, loss:0.57
# Epoch [140/10000], Step [0/1], Loss: 0.57046, Train_Acc:92.54%
# Accuary on test images:92.54%, loss:0.57
# Epoch [141/10000], Step [0/1], Loss: 0.56778, Train_Acc:92.54%
# Accuary on test images:92.54%, loss:0.57
# Epoch [142/10000], Step [0/1], Loss: 0.56514, Train_Acc:92.54%
# Accuary on test images:92.54%, loss:0.56
# Epoch [143/10000], Step [0/1], Loss: 0.56254, Train_Acc:92.54%
# Accuary on test images:92.60%, loss:0.56
# Epoch [144/10000], Step [0/1], Loss: 0.55996, Train_Acc:92.60%
# Accuary on test images:92.54%, loss:0.56
# Epoch [145/10000], Step [0/1], Loss: 0.55741, Train_Acc:92.54%
# Accuary on test images:92.54%, loss:0.55
# Epoch [146/10000], Step [0/1], Loss: 0.55490, Train_Acc:92.54%
# Accuary on test images:92.60%, loss:0.55
# Epoch [147/10000], Step [0/1], Loss: 0.55241, Train_Acc:92.60%
# Accuary on test images:92.65%, loss:0.55
# Epoch [148/10000], Step [0/1], Loss: 0.54996, Train_Acc:92.65%
# Accuary on test images:92.65%, loss:0.55
# Epoch [149/10000], Step [0/1], Loss: 0.54753, Train_Acc:92.65%
# Accuary on test images:92.65%, loss:0.55
# Epoch [150/10000], Step [0/1], Loss: 0.54513, Train_Acc:92.65%
# Accuary on test images:92.65%, loss:0.54
# Epoch [151/10000], Step [0/1], Loss: 0.54276, Train_Acc:92.65%
# Accuary on test images:92.71%, loss:0.54
# Epoch [152/10000], Step [0/1], Loss: 0.54041, Train_Acc:92.71%
# Accuary on test images:92.77%, loss:0.54
# Epoch [153/10000], Step [0/1], Loss: 0.53810, Train_Acc:92.77%
# Accuary on test images:92.77%, loss:0.54
# Epoch [154/10000], Step [0/1], Loss: 0.53581, Train_Acc:92.77%
# Accuary on test images:92.77%, loss:0.53
# Epoch [155/10000], Step [0/1], Loss: 0.53354, Train_Acc:92.77%
# Accuary on test images:92.82%, loss:0.53
# Epoch [156/10000], Step [0/1], Loss: 0.53130, Train_Acc:92.82%
# Accuary on test images:92.82%, loss:0.53
# Epoch [157/10000], Step [0/1], Loss: 0.52909, Train_Acc:92.82%
# Accuary on test images:92.82%, loss:0.53
# Epoch [158/10000], Step [0/1], Loss: 0.52690, Train_Acc:92.82%
# Accuary on test images:92.82%, loss:0.52
# Epoch [159/10000], Step [0/1], Loss: 0.52474, Train_Acc:92.82%
# Accuary on test images:92.82%, loss:0.52
# Epoch [160/10000], Step [0/1], Loss: 0.52260, Train_Acc:92.82%
# Accuary on test images:92.82%, loss:0.52
# Epoch [161/10000], Step [0/1], Loss: 0.52049, Train_Acc:92.82%
# Accuary on test images:92.88%, loss:0.52
# Epoch [162/10000], Step [0/1], Loss: 0.51839, Train_Acc:92.88%
# Accuary on test images:92.88%, loss:0.52
# Epoch [163/10000], Step [0/1], Loss: 0.51632, Train_Acc:92.88%
# Accuary on test images:92.88%, loss:0.51
# Epoch [164/10000], Step [0/1], Loss: 0.51427, Train_Acc:92.88%
# Accuary on test images:92.88%, loss:0.51
# Epoch [165/10000], Step [0/1], Loss: 0.51224, Train_Acc:92.88%
# Accuary on test images:92.93%, loss:0.51
# Epoch [166/10000], Step [0/1], Loss: 0.51024, Train_Acc:92.93%
# Accuary on test images:92.99%, loss:0.51
# Epoch [167/10000], Step [0/1], Loss: 0.50826, Train_Acc:92.99%
# Accuary on test images:93.04%, loss:0.51
# Epoch [168/10000], Step [0/1], Loss: 0.50629, Train_Acc:93.04%
# Accuary on test images:93.04%, loss:0.50
# Epoch [169/10000], Step [0/1], Loss: 0.50435, Train_Acc:93.04%
# Accuary on test images:93.04%, loss:0.50
# Epoch [170/10000], Step [0/1], Loss: 0.50243, Train_Acc:93.04%
# Accuary on test images:93.04%, loss:0.50
# Epoch [171/10000], Step [0/1], Loss: 0.50053, Train_Acc:93.04%
# Accuary on test images:93.04%, loss:0.50
# Epoch [172/10000], Step [0/1], Loss: 0.49865, Train_Acc:93.04%
# Accuary on test images:93.04%, loss:0.50
# Epoch [173/10000], Step [0/1], Loss: 0.49679, Train_Acc:93.04%
# Accuary on test images:93.04%, loss:0.49
# Epoch [174/10000], Step [0/1], Loss: 0.49495, Train_Acc:93.04%
# Accuary on test images:93.10%, loss:0.49
# Epoch [175/10000], Step [0/1], Loss: 0.49313, Train_Acc:93.10%
# Accuary on test images:93.16%, loss:0.49
# Epoch [176/10000], Step [0/1], Loss: 0.49133, Train_Acc:93.16%
# Accuary on test images:93.16%, loss:0.49
# Epoch [177/10000], Step [0/1], Loss: 0.48954, Train_Acc:93.16%
# Accuary on test images:93.16%, loss:0.49
# Epoch [178/10000], Step [0/1], Loss: 0.48778, Train_Acc:93.16%
# Accuary on test images:93.21%, loss:0.49
# Epoch [179/10000], Step [0/1], Loss: 0.48602, Train_Acc:93.21%
# Accuary on test images:93.27%, loss:0.48
# Epoch [180/10000], Step [0/1], Loss: 0.48429, Train_Acc:93.27%
# Accuary on test images:93.27%, loss:0.48
# Epoch [181/10000], Step [0/1], Loss: 0.48257, Train_Acc:93.27%
# Accuary on test images:93.27%, loss:0.48
# Epoch [182/10000], Step [0/1], Loss: 0.48087, Train_Acc:93.27%
# Accuary on test images:93.32%, loss:0.48
# Epoch [183/10000], Step [0/1], Loss: 0.47918, Train_Acc:93.32%
# Accuary on test images:93.32%, loss:0.48
# Epoch [184/10000], Step [0/1], Loss: 0.47751, Train_Acc:93.32%
# Accuary on test images:93.32%, loss:0.48
# Epoch [185/10000], Step [0/1], Loss: 0.47586, Train_Acc:93.32%
# Accuary on test images:93.32%, loss:0.47
# Epoch [186/10000], Step [0/1], Loss: 0.47422, Train_Acc:93.32%
# Accuary on test images:93.32%, loss:0.47
# Epoch [187/10000], Step [0/1], Loss: 0.47260, Train_Acc:93.32%
# Accuary on test images:93.38%, loss:0.47
# Epoch [188/10000], Step [0/1], Loss: 0.47099, Train_Acc:93.38%
# Accuary on test images:93.38%, loss:0.47
# Epoch [189/10000], Step [0/1], Loss: 0.46940, Train_Acc:93.38%
# Accuary on test images:93.43%, loss:0.47
# Epoch [190/10000], Step [0/1], Loss: 0.46782, Train_Acc:93.43%
# Accuary on test images:93.43%, loss:0.47
# Epoch [191/10000], Step [0/1], Loss: 0.46626, Train_Acc:93.43%
# Accuary on test images:93.43%, loss:0.46
# Epoch [192/10000], Step [0/1], Loss: 0.46471, Train_Acc:93.43%
# Accuary on test images:93.43%, loss:0.46
# Epoch [193/10000], Step [0/1], Loss: 0.46318, Train_Acc:93.43%
# Accuary on test images:93.43%, loss:0.46
# Epoch [194/10000], Step [0/1], Loss: 0.46166, Train_Acc:93.43%
# Accuary on test images:93.43%, loss:0.46
# Epoch [195/10000], Step [0/1], Loss: 0.46015, Train_Acc:93.43%
# Accuary on test images:93.43%, loss:0.46
# Epoch [196/10000], Step [0/1], Loss: 0.45866, Train_Acc:93.43%
# Accuary on test images:93.54%, loss:0.46
# Epoch [197/10000], Step [0/1], Loss: 0.45718, Train_Acc:93.54%
# Accuary on test images:93.54%, loss:0.46
# Epoch [198/10000], Step [0/1], Loss: 0.45572, Train_Acc:93.54%
# Accuary on test images:93.54%, loss:0.45
# Epoch [199/10000], Step [0/1], Loss: 0.45427, Train_Acc:93.54%
# Accuary on test images:93.60%, loss:0.45
# Epoch [200/10000], Step [0/1], Loss: 0.45283, Train_Acc:93.60%
# Accuary on test images:93.60%, loss:0.45
# Epoch [201/10000], Step [0/1], Loss: 0.45140, Train_Acc:93.60%
# Accuary on test images:93.60%, loss:0.45
# Epoch [202/10000], Step [0/1], Loss: 0.44998, Train_Acc:93.60%
# Accuary on test images:93.60%, loss:0.45
# Epoch [203/10000], Step [0/1], Loss: 0.44858, Train_Acc:93.60%
# Accuary on test images:93.60%, loss:0.45
# Epoch [204/10000], Step [0/1], Loss: 0.44719, Train_Acc:93.60%
# Accuary on test images:93.60%, loss:0.45
# Epoch [205/10000], Step [0/1], Loss: 0.44580, Train_Acc:93.60%
# Accuary on test images:93.66%, loss:0.44
# Epoch [206/10000], Step [0/1], Loss: 0.44443, Train_Acc:93.66%
# Accuary on test images:93.66%, loss:0.44
# Epoch [207/10000], Step [0/1], Loss: 0.44308, Train_Acc:93.66%
# Accuary on test images:93.66%, loss:0.44
# Epoch [208/10000], Step [0/1], Loss: 0.44173, Train_Acc:93.66%
# Accuary on test images:93.77%, loss:0.44
# Epoch [209/10000], Step [0/1], Loss: 0.44039, Train_Acc:93.77%
# Accuary on test images:93.77%, loss:0.44
# Epoch [210/10000], Step [0/1], Loss: 0.43907, Train_Acc:93.77%
# Accuary on test images:93.77%, loss:0.44
# Epoch [211/10000], Step [0/1], Loss: 0.43776, Train_Acc:93.77%
# Accuary on test images:93.82%, loss:0.44
# Epoch [212/10000], Step [0/1], Loss: 0.43646, Train_Acc:93.82%
# Accuary on test images:93.82%, loss:0.44
# Epoch [213/10000], Step [0/1], Loss: 0.43517, Train_Acc:93.82%
# Accuary on test images:93.88%, loss:0.43
# Epoch [214/10000], Step [0/1], Loss: 0.43388, Train_Acc:93.88%
# Accuary on test images:93.88%, loss:0.43
# Epoch [215/10000], Step [0/1], Loss: 0.43261, Train_Acc:93.88%
# Accuary on test images:93.88%, loss:0.43
# Epoch [216/10000], Step [0/1], Loss: 0.43135, Train_Acc:93.88%
# Accuary on test images:93.88%, loss:0.43
# Epoch [217/10000], Step [0/1], Loss: 0.43010, Train_Acc:93.88%
# Accuary on test images:93.88%, loss:0.43
# Epoch [218/10000], Step [0/1], Loss: 0.42886, Train_Acc:93.88%
# Accuary on test images:93.88%, loss:0.43
# Epoch [219/10000], Step [0/1], Loss: 0.42763, Train_Acc:93.88%
# Accuary on test images:93.99%, loss:0.43
# Epoch [220/10000], Step [0/1], Loss: 0.42640, Train_Acc:93.99%
# Accuary on test images:93.99%, loss:0.43
# Epoch [221/10000], Step [0/1], Loss: 0.42519, Train_Acc:93.99%
# Accuary on test images:93.99%, loss:0.42
# Epoch [222/10000], Step [0/1], Loss: 0.42399, Train_Acc:93.99%
# Accuary on test images:93.99%, loss:0.42
# Epoch [223/10000], Step [0/1], Loss: 0.42280, Train_Acc:93.99%
# Accuary on test images:94.05%, loss:0.42
# Epoch [224/10000], Step [0/1], Loss: 0.42161, Train_Acc:94.05%
# Accuary on test images:94.05%, loss:0.42
# Epoch [225/10000], Step [0/1], Loss: 0.42044, Train_Acc:94.05%
# Accuary on test images:94.05%, loss:0.42
# Epoch [226/10000], Step [0/1], Loss: 0.41928, Train_Acc:94.05%
# Accuary on test images:94.05%, loss:0.42
# Epoch [227/10000], Step [0/1], Loss: 0.41813, Train_Acc:94.05%
# Accuary on test images:94.05%, loss:0.42
# Epoch [228/10000], Step [0/1], Loss: 0.41698, Train_Acc:94.05%
# Accuary on test images:94.10%, loss:0.42
# Epoch [229/10000], Step [0/1], Loss: 0.41585, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.41
# Epoch [230/10000], Step [0/1], Loss: 0.41472, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.41
# Epoch [231/10000], Step [0/1], Loss: 0.41360, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.41
# Epoch [232/10000], Step [0/1], Loss: 0.41249, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.41
# Epoch [233/10000], Step [0/1], Loss: 0.41139, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.41
# Epoch [234/10000], Step [0/1], Loss: 0.41030, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.41
# Epoch [235/10000], Step [0/1], Loss: 0.40921, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.41
# Epoch [236/10000], Step [0/1], Loss: 0.40813, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.41
# Epoch [237/10000], Step [0/1], Loss: 0.40706, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.41
# Epoch [238/10000], Step [0/1], Loss: 0.40600, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.40
# Epoch [239/10000], Step [0/1], Loss: 0.40494, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.40
# Epoch [240/10000], Step [0/1], Loss: 0.40390, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.40
# Epoch [241/10000], Step [0/1], Loss: 0.40285, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.40
# Epoch [242/10000], Step [0/1], Loss: 0.40182, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.40
# Epoch [243/10000], Step [0/1], Loss: 0.40080, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.40
# Epoch [244/10000], Step [0/1], Loss: 0.39978, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.40
# Epoch [245/10000], Step [0/1], Loss: 0.39876, Train_Acc:94.10%
# Accuary on test images:94.10%, loss:0.40
# Epoch [246/10000], Step [0/1], Loss: 0.39776, Train_Acc:94.10%
# Accuary on test images:94.21%, loss:0.40
# Epoch [247/10000], Step [0/1], Loss: 0.39676, Train_Acc:94.21%
# Accuary on test images:94.21%, loss:0.40
# Epoch [248/10000], Step [0/1], Loss: 0.39577, Train_Acc:94.21%
# Accuary on test images:94.21%, loss:0.39
# Epoch [249/10000], Step [0/1], Loss: 0.39479, Train_Acc:94.21%
# Accuary on test images:94.21%, loss:0.39
# Epoch [250/10000], Step [0/1], Loss: 0.39381, Train_Acc:94.21%
# Accuary on test images:94.21%, loss:0.39
# Epoch [251/10000], Step [0/1], Loss: 0.39284, Train_Acc:94.21%
# Accuary on test images:94.21%, loss:0.39
# Epoch [252/10000], Step [0/1], Loss: 0.39188, Train_Acc:94.21%
# Accuary on test images:94.21%, loss:0.39
# Epoch [253/10000], Step [0/1], Loss: 0.39092, Train_Acc:94.21%
# Accuary on test images:94.21%, loss:0.39
# Epoch [254/10000], Step [0/1], Loss: 0.38998, Train_Acc:94.21%
# Accuary on test images:94.27%, loss:0.39
# Epoch [255/10000], Step [0/1], Loss: 0.38903, Train_Acc:94.27%
# Accuary on test images:94.27%, loss:0.39
# Epoch [256/10000], Step [0/1], Loss: 0.38810, Train_Acc:94.27%
# Accuary on test images:94.27%, loss:0.39
# Epoch [257/10000], Step [0/1], Loss: 0.38717, Train_Acc:94.27%
# Accuary on test images:94.27%, loss:0.39
# Epoch [258/10000], Step [0/1], Loss: 0.38624, Train_Acc:94.27%
# Accuary on test images:94.27%, loss:0.39
# Epoch [259/10000], Step [0/1], Loss: 0.38532, Train_Acc:94.27%
# Accuary on test images:94.27%, loss:0.38
# Epoch [260/10000], Step [0/1], Loss: 0.38441, Train_Acc:94.27%
# Accuary on test images:94.27%, loss:0.38
# Epoch [261/10000], Step [0/1], Loss: 0.38351, Train_Acc:94.27%
# Accuary on test images:94.27%, loss:0.38
# Epoch [262/10000], Step [0/1], Loss: 0.38261, Train_Acc:94.27%
# Accuary on test images:94.27%, loss:0.38
# Epoch [263/10000], Step [0/1], Loss: 0.38171, Train_Acc:94.27%
# Accuary on test images:94.32%, loss:0.38
# Epoch [264/10000], Step [0/1], Loss: 0.38083, Train_Acc:94.32%
# Accuary on test images:94.32%, loss:0.38
# Epoch [265/10000], Step [0/1], Loss: 0.37994, Train_Acc:94.32%
# Accuary on test images:94.32%, loss:0.38
# Epoch [266/10000], Step [0/1], Loss: 0.37907, Train_Acc:94.32%
# Accuary on test images:94.32%, loss:0.38
# Epoch [267/10000], Step [0/1], Loss: 0.37820, Train_Acc:94.32%
# Accuary on test images:94.38%, loss:0.38
# Epoch [268/10000], Step [0/1], Loss: 0.37733, Train_Acc:94.38%
# Accuary on test images:94.38%, loss:0.38
# Epoch [269/10000], Step [0/1], Loss: 0.37647, Train_Acc:94.38%
# Accuary on test images:94.38%, loss:0.38
# Epoch [270/10000], Step [0/1], Loss: 0.37561, Train_Acc:94.38%
# Accuary on test images:94.38%, loss:0.37
# Epoch [271/10000], Step [0/1], Loss: 0.37476, Train_Acc:94.38%
# Accuary on test images:94.44%, loss:0.37
# Epoch [272/10000], Step [0/1], Loss: 0.37392, Train_Acc:94.44%
# Accuary on test images:94.44%, loss:0.37
# Epoch [273/10000], Step [0/1], Loss: 0.37308, Train_Acc:94.44%
# Accuary on test images:94.44%, loss:0.37
# Epoch [274/10000], Step [0/1], Loss: 0.37225, Train_Acc:94.44%
# Accuary on test images:94.44%, loss:0.37
# Epoch [275/10000], Step [0/1], Loss: 0.37142, Train_Acc:94.44%
# Accuary on test images:94.44%, loss:0.37
# Epoch [276/10000], Step [0/1], Loss: 0.37060, Train_Acc:94.44%
# Accuary on test images:94.44%, loss:0.37
# Epoch [277/10000], Step [0/1], Loss: 0.36978, Train_Acc:94.44%
# Accuary on test images:94.44%, loss:0.37
# Epoch [278/10000], Step [0/1], Loss: 0.36897, Train_Acc:94.44%
# Accuary on test images:94.44%, loss:0.37
# Epoch [279/10000], Step [0/1], Loss: 0.36817, Train_Acc:94.44%
# Accuary on test images:94.44%, loss:0.37
# Epoch [280/10000], Step [0/1], Loss: 0.36737, Train_Acc:94.44%
# Accuary on test images:94.44%, loss:0.37
# Epoch [281/10000], Step [0/1], Loss: 0.36657, Train_Acc:94.44%
# Accuary on test images:94.44%, loss:0.37
# Epoch [282/10000], Step [0/1], Loss: 0.36578, Train_Acc:94.44%
# Accuary on test images:94.49%, loss:0.36
# Epoch [283/10000], Step [0/1], Loss: 0.36500, Train_Acc:94.49%
# Accuary on test images:94.49%, loss:0.36
# Epoch [284/10000], Step [0/1], Loss: 0.36422, Train_Acc:94.49%
# Accuary on test images:94.49%, loss:0.36
# Epoch [285/10000], Step [0/1], Loss: 0.36344, Train_Acc:94.49%
# Accuary on test images:94.49%, loss:0.36
# Epoch [286/10000], Step [0/1], Loss: 0.36267, Train_Acc:94.49%
# Accuary on test images:94.55%, loss:0.36
# Epoch [287/10000], Step [0/1], Loss: 0.36190, Train_Acc:94.55%
# Accuary on test images:94.60%, loss:0.36
# Epoch [288/10000], Step [0/1], Loss: 0.36114, Train_Acc:94.60%
# Accuary on test images:94.60%, loss:0.36
# Epoch [289/10000], Step [0/1], Loss: 0.36038, Train_Acc:94.60%
# Accuary on test images:94.66%, loss:0.36
# Epoch [290/10000], Step [0/1], Loss: 0.35963, Train_Acc:94.66%
# Accuary on test images:94.66%, loss:0.36
# Epoch [291/10000], Step [0/1], Loss: 0.35888, Train_Acc:94.66%
# Accuary on test images:94.71%, loss:0.36
# Epoch [292/10000], Step [0/1], Loss: 0.35814, Train_Acc:94.71%
# Accuary on test images:94.71%, loss:0.36
# Epoch [293/10000], Step [0/1], Loss: 0.35739, Train_Acc:94.71%
# Accuary on test images:94.71%, loss:0.36
# Epoch [294/10000], Step [0/1], Loss: 0.35666, Train_Acc:94.71%
# Accuary on test images:94.71%, loss:0.36
# Epoch [295/10000], Step [0/1], Loss: 0.35593, Train_Acc:94.71%
# Accuary on test images:94.71%, loss:0.36
# Epoch [296/10000], Step [0/1], Loss: 0.35520, Train_Acc:94.71%
# Accuary on test images:94.71%, loss:0.35
# Epoch [297/10000], Step [0/1], Loss: 0.35447, Train_Acc:94.71%
# Accuary on test images:94.71%, loss:0.35
# Epoch [298/10000], Step [0/1], Loss: 0.35376, Train_Acc:94.71%
# Accuary on test images:94.71%, loss:0.35
# Epoch [299/10000], Step [0/1], Loss: 0.35304, Train_Acc:94.71%
# Accuary on test images:94.71%, loss:0.35
# Epoch [300/10000], Step [0/1], Loss: 0.35233, Train_Acc:94.71%
# Accuary on test images:94.71%, loss:0.35
# Epoch [301/10000], Step [0/1], Loss: 0.35162, Train_Acc:94.71%
# Accuary on test images:94.71%, loss:0.35
# Epoch [302/10000], Step [0/1], Loss: 0.35092, Train_Acc:94.71%
# Accuary on test images:94.71%, loss:0.35
# Epoch [303/10000], Step [0/1], Loss: 0.35022, Train_Acc:94.71%
# Accuary on test images:94.71%, loss:0.35
# Epoch [304/10000], Step [0/1], Loss: 0.34953, Train_Acc:94.71%
# Accuary on test images:94.77%, loss:0.35
# Epoch [305/10000], Step [0/1], Loss: 0.34883, Train_Acc:94.77%
# Accuary on test images:94.77%, loss:0.35
# Epoch [306/10000], Step [0/1], Loss: 0.34815, Train_Acc:94.77%
# Accuary on test images:94.77%, loss:0.35
# Epoch [307/10000], Step [0/1], Loss: 0.34746, Train_Acc:94.77%
# Accuary on test images:94.82%, loss:0.35
# Epoch [308/10000], Step [0/1], Loss: 0.34678, Train_Acc:94.82%
# Accuary on test images:94.82%, loss:0.35
# Epoch [309/10000], Step [0/1], Loss: 0.34611, Train_Acc:94.82%
# Accuary on test images:94.82%, loss:0.35
# Epoch [310/10000], Step [0/1], Loss: 0.34543, Train_Acc:94.82%
# Accuary on test images:94.94%, loss:0.34
# Epoch [311/10000], Step [0/1], Loss: 0.34476, Train_Acc:94.94%
# Accuary on test images:94.94%, loss:0.34
# Epoch [312/10000], Step [0/1], Loss: 0.34410, Train_Acc:94.94%
# Accuary on test images:94.94%, loss:0.34
# Epoch [313/10000], Step [0/1], Loss: 0.34344, Train_Acc:94.94%
# Accuary on test images:94.94%, loss:0.34
# Epoch [314/10000], Step [0/1], Loss: 0.34278, Train_Acc:94.94%
# Accuary on test images:94.94%, loss:0.34
# Epoch [315/10000], Step [0/1], Loss: 0.34212, Train_Acc:94.94%
# Accuary on test images:94.94%, loss:0.34
# Epoch [316/10000], Step [0/1], Loss: 0.34147, Train_Acc:94.94%
# Accuary on test images:95.05%, loss:0.34
# Epoch [317/10000], Step [0/1], Loss: 0.34083, Train_Acc:95.05%
# Accuary on test images:95.10%, loss:0.34
# Epoch [318/10000], Step [0/1], Loss: 0.34018, Train_Acc:95.10%
# Accuary on test images:95.10%, loss:0.34
# Epoch [319/10000], Step [0/1], Loss: 0.33954, Train_Acc:95.10%
# Accuary on test images:95.10%, loss:0.34
# Epoch [320/10000], Step [0/1], Loss: 0.33891, Train_Acc:95.10%
# Accuary on test images:95.10%, loss:0.34
# Epoch [321/10000], Step [0/1], Loss: 0.33828, Train_Acc:95.10%
# Accuary on test images:95.10%, loss:0.34
# Epoch [322/10000], Step [0/1], Loss: 0.33765, Train_Acc:95.10%
# Accuary on test images:95.10%, loss:0.34
# Epoch [323/10000], Step [0/1], Loss: 0.33702, Train_Acc:95.10%
# Accuary on test images:95.10%, loss:0.34
# Epoch [324/10000], Step [0/1], Loss: 0.33640, Train_Acc:95.10%
# Accuary on test images:95.16%, loss:0.34
# Epoch [325/10000], Step [0/1], Loss: 0.33578, Train_Acc:95.16%
# Accuary on test images:95.16%, loss:0.34
# Epoch [326/10000], Step [0/1], Loss: 0.33517, Train_Acc:95.16%
# Accuary on test images:95.16%, loss:0.33
# Epoch [327/10000], Step [0/1], Loss: 0.33456, Train_Acc:95.16%
# Accuary on test images:95.16%, loss:0.33
# Epoch [328/10000], Step [0/1], Loss: 0.33395, Train_Acc:95.16%
# Accuary on test images:95.16%, loss:0.33
# Epoch [329/10000], Step [0/1], Loss: 0.33335, Train_Acc:95.16%
# Accuary on test images:95.16%, loss:0.33
# Epoch [330/10000], Step [0/1], Loss: 0.33275, Train_Acc:95.16%
# Accuary on test images:95.16%, loss:0.33
# Epoch [331/10000], Step [0/1], Loss: 0.33215, Train_Acc:95.16%
# Accuary on test images:95.21%, loss:0.33
# Epoch [332/10000], Step [0/1], Loss: 0.33155, Train_Acc:95.21%
# Accuary on test images:95.21%, loss:0.33
# Epoch [333/10000], Step [0/1], Loss: 0.33096, Train_Acc:95.21%
# Accuary on test images:95.21%, loss:0.33
# Epoch [334/10000], Step [0/1], Loss: 0.33037, Train_Acc:95.21%
# Accuary on test images:95.27%, loss:0.33
# Epoch [335/10000], Step [0/1], Loss: 0.32978, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.33
# Epoch [336/10000], Step [0/1], Loss: 0.32920, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.33
# Epoch [337/10000], Step [0/1], Loss: 0.32862, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.33
# Epoch [338/10000], Step [0/1], Loss: 0.32804, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.33
# Epoch [339/10000], Step [0/1], Loss: 0.32746, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.33
# Epoch [340/10000], Step [0/1], Loss: 0.32689, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.33
# Epoch [341/10000], Step [0/1], Loss: 0.32632, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.33
# Epoch [342/10000], Step [0/1], Loss: 0.32575, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.33
# Epoch [343/10000], Step [0/1], Loss: 0.32519, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.32
# Epoch [344/10000], Step [0/1], Loss: 0.32463, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.32
# Epoch [345/10000], Step [0/1], Loss: 0.32407, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.32
# Epoch [346/10000], Step [0/1], Loss: 0.32352, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.32
# Epoch [347/10000], Step [0/1], Loss: 0.32296, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.32
# Epoch [348/10000], Step [0/1], Loss: 0.32241, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.32
# Epoch [349/10000], Step [0/1], Loss: 0.32187, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.32
# Epoch [350/10000], Step [0/1], Loss: 0.32132, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.32
# Epoch [351/10000], Step [0/1], Loss: 0.32078, Train_Acc:95.27%
# Accuary on test images:95.27%, loss:0.32
# Epoch [352/10000], Step [0/1], Loss: 0.32024, Train_Acc:95.27%
# Accuary on test images:95.33%, loss:0.32
# Epoch [353/10000], Step [0/1], Loss: 0.31970, Train_Acc:95.33%
# Accuary on test images:95.33%, loss:0.32
# Epoch [354/10000], Step [0/1], Loss: 0.31916, Train_Acc:95.33%
# Accuary on test images:95.33%, loss:0.32
# Epoch [355/10000], Step [0/1], Loss: 0.31863, Train_Acc:95.33%
# Accuary on test images:95.33%, loss:0.32
# Epoch [356/10000], Step [0/1], Loss: 0.31810, Train_Acc:95.33%
# Accuary on test images:95.33%, loss:0.32
# Epoch [357/10000], Step [0/1], Loss: 0.31758, Train_Acc:95.33%
# Accuary on test images:95.33%, loss:0.32
# Epoch [358/10000], Step [0/1], Loss: 0.31705, Train_Acc:95.33%
# Accuary on test images:95.33%, loss:0.32
# Epoch [359/10000], Step [0/1], Loss: 0.31653, Train_Acc:95.33%
# Accuary on test images:95.33%, loss:0.32
# Epoch [360/10000], Step [0/1], Loss: 0.31601, Train_Acc:95.33%
# Accuary on test images:95.33%, loss:0.32
# Epoch [361/10000], Step [0/1], Loss: 0.31549, Train_Acc:95.33%
# Accuary on test images:95.33%, loss:0.31
# Epoch [362/10000], Step [0/1], Loss: 0.31498, Train_Acc:95.33%
# Accuary on test images:95.33%, loss:0.31
# Epoch [363/10000], Step [0/1], Loss: 0.31446, Train_Acc:95.33%
# Accuary on test images:95.38%, loss:0.31
# Epoch [364/10000], Step [0/1], Loss: 0.31395, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [365/10000], Step [0/1], Loss: 0.31345, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [366/10000], Step [0/1], Loss: 0.31294, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [367/10000], Step [0/1], Loss: 0.31244, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [368/10000], Step [0/1], Loss: 0.31194, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [369/10000], Step [0/1], Loss: 0.31144, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [370/10000], Step [0/1], Loss: 0.31095, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [371/10000], Step [0/1], Loss: 0.31045, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [372/10000], Step [0/1], Loss: 0.30996, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [373/10000], Step [0/1], Loss: 0.30947, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [374/10000], Step [0/1], Loss: 0.30898, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [375/10000], Step [0/1], Loss: 0.30850, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [376/10000], Step [0/1], Loss: 0.30801, Train_Acc:95.38%
# Accuary on test images:95.38%, loss:0.31
# Epoch [377/10000], Step [0/1], Loss: 0.30753, Train_Acc:95.38%
# Accuary on test images:95.44%, loss:0.31
# Epoch [378/10000], Step [0/1], Loss: 0.30705, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.31
# Epoch [379/10000], Step [0/1], Loss: 0.30658, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.31
# Epoch [380/10000], Step [0/1], Loss: 0.30610, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.31
# Epoch [381/10000], Step [0/1], Loss: 0.30563, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.31
# Epoch [382/10000], Step [0/1], Loss: 0.30516, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [383/10000], Step [0/1], Loss: 0.30469, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [384/10000], Step [0/1], Loss: 0.30423, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [385/10000], Step [0/1], Loss: 0.30376, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [386/10000], Step [0/1], Loss: 0.30330, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [387/10000], Step [0/1], Loss: 0.30284, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [388/10000], Step [0/1], Loss: 0.30238, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [389/10000], Step [0/1], Loss: 0.30193, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [390/10000], Step [0/1], Loss: 0.30148, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [391/10000], Step [0/1], Loss: 0.30102, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [392/10000], Step [0/1], Loss: 0.30057, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [393/10000], Step [0/1], Loss: 0.30013, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [394/10000], Step [0/1], Loss: 0.29968, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [395/10000], Step [0/1], Loss: 0.29924, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [396/10000], Step [0/1], Loss: 0.29879, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [397/10000], Step [0/1], Loss: 0.29835, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [398/10000], Step [0/1], Loss: 0.29792, Train_Acc:95.44%
# Accuary on test images:95.44%, loss:0.30
# Epoch [399/10000], Step [0/1], Loss: 0.29748, Train_Acc:95.44%
# Accuary on test images:95.49%, loss:0.30
# Epoch [400/10000], Step [0/1], Loss: 0.29704, Train_Acc:95.49%
# Accuary on test images:95.49%, loss:0.30
# Epoch [401/10000], Step [0/1], Loss: 0.29661, Train_Acc:95.49%
# Accuary on test images:95.55%, loss:0.30
# Epoch [402/10000], Step [0/1], Loss: 0.29618, Train_Acc:95.55%
# Accuary on test images:95.55%, loss:0.30
# Epoch [403/10000], Step [0/1], Loss: 0.29575, Train_Acc:95.55%
# Accuary on test images:95.55%, loss:0.30
# Epoch [404/10000], Step [0/1], Loss: 0.29532, Train_Acc:95.55%
# Accuary on test images:95.55%, loss:0.29
# Epoch [405/10000], Step [0/1], Loss: 0.29489, Train_Acc:95.55%
# Accuary on test images:95.55%, loss:0.29
# Epoch [406/10000], Step [0/1], Loss: 0.29447, Train_Acc:95.55%
# Accuary on test images:95.60%, loss:0.29
# Epoch [407/10000], Step [0/1], Loss: 0.29405, Train_Acc:95.60%
# Accuary on test images:95.60%, loss:0.29
# Epoch [408/10000], Step [0/1], Loss: 0.29362, Train_Acc:95.60%
# Accuary on test images:95.60%, loss:0.29
# Epoch [409/10000], Step [0/1], Loss: 0.29320, Train_Acc:95.60%
# Accuary on test images:95.60%, loss:0.29
# Epoch [410/10000], Step [0/1], Loss: 0.29279, Train_Acc:95.60%
# Accuary on test images:95.60%, loss:0.29
# Epoch [411/10000], Step [0/1], Loss: 0.29237, Train_Acc:95.60%
# Accuary on test images:95.60%, loss:0.29
# Epoch [412/10000], Step [0/1], Loss: 0.29195, Train_Acc:95.60%
# Accuary on test images:95.60%, loss:0.29
# Epoch [413/10000], Step [0/1], Loss: 0.29154, Train_Acc:95.60%
# Accuary on test images:95.60%, loss:0.29
# Epoch [414/10000], Step [0/1], Loss: 0.29113, Train_Acc:95.60%
# Accuary on test images:95.60%, loss:0.29
# Epoch [415/10000], Step [0/1], Loss: 0.29072, Train_Acc:95.60%
# Accuary on test images:95.66%, loss:0.29
# Epoch [416/10000], Step [0/1], Loss: 0.29031, Train_Acc:95.66%
# Accuary on test images:95.72%, loss:0.29
# Epoch [417/10000], Step [0/1], Loss: 0.28990, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.29
# Epoch [418/10000], Step [0/1], Loss: 0.28950, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.29
# Epoch [419/10000], Step [0/1], Loss: 0.28909, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.29
# Epoch [420/10000], Step [0/1], Loss: 0.28869, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.29
# Epoch [421/10000], Step [0/1], Loss: 0.28829, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.29
# Epoch [422/10000], Step [0/1], Loss: 0.28789, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.29
# Epoch [423/10000], Step [0/1], Loss: 0.28750, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.29
# Epoch [424/10000], Step [0/1], Loss: 0.28710, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.29
# Epoch [425/10000], Step [0/1], Loss: 0.28671, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.29
# Epoch [426/10000], Step [0/1], Loss: 0.28631, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.29
# Epoch [427/10000], Step [0/1], Loss: 0.28592, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.29
# Epoch [428/10000], Step [0/1], Loss: 0.28553, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.29
# Epoch [429/10000], Step [0/1], Loss: 0.28514, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.28
# Epoch [430/10000], Step [0/1], Loss: 0.28476, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.28
# Epoch [431/10000], Step [0/1], Loss: 0.28437, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.28
# Epoch [432/10000], Step [0/1], Loss: 0.28399, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.28
# Epoch [433/10000], Step [0/1], Loss: 0.28361, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.28
# Epoch [434/10000], Step [0/1], Loss: 0.28322, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.28
# Epoch [435/10000], Step [0/1], Loss: 0.28285, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.28
# Epoch [436/10000], Step [0/1], Loss: 0.28247, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.28
# Epoch [437/10000], Step [0/1], Loss: 0.28209, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.28
# Epoch [438/10000], Step [0/1], Loss: 0.28172, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.28
# Epoch [439/10000], Step [0/1], Loss: 0.28134, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.28
# Epoch [440/10000], Step [0/1], Loss: 0.28097, Train_Acc:95.72%
# Accuary on test images:95.72%, loss:0.28
# Epoch [441/10000], Step [0/1], Loss: 0.28060, Train_Acc:95.72%
# Accuary on test images:95.77%, loss:0.28
# Epoch [442/10000], Step [0/1], Loss: 0.28023, Train_Acc:95.77%
# Accuary on test images:95.77%, loss:0.28
# Epoch [443/10000], Step [0/1], Loss: 0.27986, Train_Acc:95.77%
# Accuary on test images:95.77%, loss:0.28
# Epoch [444/10000], Step [0/1], Loss: 0.27949, Train_Acc:95.77%
# Accuary on test images:95.77%, loss:0.28
# Epoch [445/10000], Step [0/1], Loss: 0.27913, Train_Acc:95.77%
# Accuary on test images:95.77%, loss:0.28
# Epoch [446/10000], Step [0/1], Loss: 0.27877, Train_Acc:95.77%
# Accuary on test images:95.77%, loss:0.28
# Epoch [447/10000], Step [0/1], Loss: 0.27840, Train_Acc:95.77%
# Accuary on test images:95.77%, loss:0.28
# Epoch [448/10000], Step [0/1], Loss: 0.27804, Train_Acc:95.77%
# Accuary on test images:95.77%, loss:0.28
# Epoch [449/10000], Step [0/1], Loss: 0.27768, Train_Acc:95.77%
# Accuary on test images:95.77%, loss:0.28
# Epoch [450/10000], Step [0/1], Loss: 0.27732, Train_Acc:95.77%
# Accuary on test images:95.77%, loss:0.28
# Epoch [451/10000], Step [0/1], Loss: 0.27697, Train_Acc:95.77%
# Accuary on test images:95.77%, loss:0.28
# Epoch [452/10000], Step [0/1], Loss: 0.27661, Train_Acc:95.77%
# Accuary on test images:95.77%, loss:0.28
# Epoch [453/10000], Step [0/1], Loss: 0.27625, Train_Acc:95.77%
# Accuary on test images:95.83%, loss:0.28
# Epoch [454/10000], Step [0/1], Loss: 0.27590, Train_Acc:95.83%
# Accuary on test images:95.83%, loss:0.28
# Epoch [455/10000], Step [0/1], Loss: 0.27555, Train_Acc:95.83%
# Accuary on test images:95.83%, loss:0.28
# Epoch [456/10000], Step [0/1], Loss: 0.27520, Train_Acc:95.83%
# Accuary on test images:95.83%, loss:0.27
# Epoch [457/10000], Step [0/1], Loss: 0.27485, Train_Acc:95.83%
# Accuary on test images:95.83%, loss:0.27
# Epoch [458/10000], Step [0/1], Loss: 0.27450, Train_Acc:95.83%
# Accuary on test images:95.83%, loss:0.27
# Epoch [459/10000], Step [0/1], Loss: 0.27415, Train_Acc:95.83%
# Accuary on test images:95.83%, loss:0.27
# Epoch [460/10000], Step [0/1], Loss: 0.27381, Train_Acc:95.83%
# Accuary on test images:95.83%, loss:0.27
# Epoch [461/10000], Step [0/1], Loss: 0.27346, Train_Acc:95.83%
# Accuary on test images:95.83%, loss:0.27
# ...
# Accuary on test images:99.78%, loss:0.04
# Epoch [9850/10000], Step [0/1], Loss: 0.04485, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9851/10000], Step [0/1], Loss: 0.04485, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9852/10000], Step [0/1], Loss: 0.04485, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9853/10000], Step [0/1], Loss: 0.04484, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9854/10000], Step [0/1], Loss: 0.04484, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9855/10000], Step [0/1], Loss: 0.04484, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9856/10000], Step [0/1], Loss: 0.04483, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9857/10000], Step [0/1], Loss: 0.04483, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9858/10000], Step [0/1], Loss: 0.04483, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9859/10000], Step [0/1], Loss: 0.04482, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9860/10000], Step [0/1], Loss: 0.04482, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9861/10000], Step [0/1], Loss: 0.04482, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9862/10000], Step [0/1], Loss: 0.04482, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9863/10000], Step [0/1], Loss: 0.04481, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9864/10000], Step [0/1], Loss: 0.04481, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9865/10000], Step [0/1], Loss: 0.04481, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9866/10000], Step [0/1], Loss: 0.04480, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9867/10000], Step [0/1], Loss: 0.04480, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9868/10000], Step [0/1], Loss: 0.04480, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9869/10000], Step [0/1], Loss: 0.04479, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9870/10000], Step [0/1], Loss: 0.04479, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9871/10000], Step [0/1], Loss: 0.04479, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9872/10000], Step [0/1], Loss: 0.04479, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9873/10000], Step [0/1], Loss: 0.04478, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9874/10000], Step [0/1], Loss: 0.04478, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9875/10000], Step [0/1], Loss: 0.04478, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9876/10000], Step [0/1], Loss: 0.04477, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9877/10000], Step [0/1], Loss: 0.04477, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9878/10000], Step [0/1], Loss: 0.04477, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9879/10000], Step [0/1], Loss: 0.04476, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9880/10000], Step [0/1], Loss: 0.04476, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9881/10000], Step [0/1], Loss: 0.04476, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9882/10000], Step [0/1], Loss: 0.04475, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9883/10000], Step [0/1], Loss: 0.04475, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9884/10000], Step [0/1], Loss: 0.04475, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9885/10000], Step [0/1], Loss: 0.04475, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9886/10000], Step [0/1], Loss: 0.04474, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9887/10000], Step [0/1], Loss: 0.04474, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9888/10000], Step [0/1], Loss: 0.04474, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9889/10000], Step [0/1], Loss: 0.04473, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9890/10000], Step [0/1], Loss: 0.04473, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9891/10000], Step [0/1], Loss: 0.04473, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9892/10000], Step [0/1], Loss: 0.04472, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9893/10000], Step [0/1], Loss: 0.04472, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9894/10000], Step [0/1], Loss: 0.04472, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9895/10000], Step [0/1], Loss: 0.04472, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9896/10000], Step [0/1], Loss: 0.04471, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9897/10000], Step [0/1], Loss: 0.04471, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9898/10000], Step [0/1], Loss: 0.04471, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9899/10000], Step [0/1], Loss: 0.04470, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9900/10000], Step [0/1], Loss: 0.04470, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9901/10000], Step [0/1], Loss: 0.04470, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9902/10000], Step [0/1], Loss: 0.04469, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9903/10000], Step [0/1], Loss: 0.04469, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9904/10000], Step [0/1], Loss: 0.04469, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9905/10000], Step [0/1], Loss: 0.04469, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9906/10000], Step [0/1], Loss: 0.04468, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9907/10000], Step [0/1], Loss: 0.04468, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9908/10000], Step [0/1], Loss: 0.04468, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9909/10000], Step [0/1], Loss: 0.04467, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9910/10000], Step [0/1], Loss: 0.04467, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9911/10000], Step [0/1], Loss: 0.04467, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9912/10000], Step [0/1], Loss: 0.04466, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9913/10000], Step [0/1], Loss: 0.04466, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9914/10000], Step [0/1], Loss: 0.04466, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9915/10000], Step [0/1], Loss: 0.04465, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9916/10000], Step [0/1], Loss: 0.04465, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9917/10000], Step [0/1], Loss: 0.04465, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9918/10000], Step [0/1], Loss: 0.04465, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9919/10000], Step [0/1], Loss: 0.04464, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9920/10000], Step [0/1], Loss: 0.04464, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9921/10000], Step [0/1], Loss: 0.04464, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9922/10000], Step [0/1], Loss: 0.04463, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9923/10000], Step [0/1], Loss: 0.04463, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9924/10000], Step [0/1], Loss: 0.04463, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9925/10000], Step [0/1], Loss: 0.04462, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9926/10000], Step [0/1], Loss: 0.04462, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9927/10000], Step [0/1], Loss: 0.04462, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9928/10000], Step [0/1], Loss: 0.04462, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9929/10000], Step [0/1], Loss: 0.04461, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9930/10000], Step [0/1], Loss: 0.04461, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9931/10000], Step [0/1], Loss: 0.04461, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9932/10000], Step [0/1], Loss: 0.04460, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9933/10000], Step [0/1], Loss: 0.04460, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9934/10000], Step [0/1], Loss: 0.04460, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9935/10000], Step [0/1], Loss: 0.04459, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9936/10000], Step [0/1], Loss: 0.04459, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9937/10000], Step [0/1], Loss: 0.04459, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9938/10000], Step [0/1], Loss: 0.04459, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9939/10000], Step [0/1], Loss: 0.04458, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9940/10000], Step [0/1], Loss: 0.04458, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9941/10000], Step [0/1], Loss: 0.04458, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9942/10000], Step [0/1], Loss: 0.04457, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9943/10000], Step [0/1], Loss: 0.04457, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9944/10000], Step [0/1], Loss: 0.04457, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9945/10000], Step [0/1], Loss: 0.04456, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9946/10000], Step [0/1], Loss: 0.04456, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9947/10000], Step [0/1], Loss: 0.04456, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9948/10000], Step [0/1], Loss: 0.04456, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9949/10000], Step [0/1], Loss: 0.04455, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9950/10000], Step [0/1], Loss: 0.04455, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9951/10000], Step [0/1], Loss: 0.04455, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9952/10000], Step [0/1], Loss: 0.04454, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9953/10000], Step [0/1], Loss: 0.04454, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9954/10000], Step [0/1], Loss: 0.04454, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9955/10000], Step [0/1], Loss: 0.04453, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9956/10000], Step [0/1], Loss: 0.04453, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9957/10000], Step [0/1], Loss: 0.04453, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9958/10000], Step [0/1], Loss: 0.04453, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9959/10000], Step [0/1], Loss: 0.04452, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9960/10000], Step [0/1], Loss: 0.04452, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9961/10000], Step [0/1], Loss: 0.04452, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9962/10000], Step [0/1], Loss: 0.04451, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9963/10000], Step [0/1], Loss: 0.04451, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9964/10000], Step [0/1], Loss: 0.04451, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9965/10000], Step [0/1], Loss: 0.04450, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9966/10000], Step [0/1], Loss: 0.04450, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9967/10000], Step [0/1], Loss: 0.04450, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9968/10000], Step [0/1], Loss: 0.04450, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9969/10000], Step [0/1], Loss: 0.04449, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9970/10000], Step [0/1], Loss: 0.04449, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9971/10000], Step [0/1], Loss: 0.04449, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9972/10000], Step [0/1], Loss: 0.04448, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9973/10000], Step [0/1], Loss: 0.04448, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9974/10000], Step [0/1], Loss: 0.04448, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9975/10000], Step [0/1], Loss: 0.04447, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9976/10000], Step [0/1], Loss: 0.04447, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9977/10000], Step [0/1], Loss: 0.04447, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9978/10000], Step [0/1], Loss: 0.04447, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9979/10000], Step [0/1], Loss: 0.04446, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9980/10000], Step [0/1], Loss: 0.04446, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9981/10000], Step [0/1], Loss: 0.04446, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9982/10000], Step [0/1], Loss: 0.04445, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9983/10000], Step [0/1], Loss: 0.04445, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9984/10000], Step [0/1], Loss: 0.04445, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9985/10000], Step [0/1], Loss: 0.04444, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9986/10000], Step [0/1], Loss: 0.04444, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9987/10000], Step [0/1], Loss: 0.04444, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9988/10000], Step [0/1], Loss: 0.04444, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9989/10000], Step [0/1], Loss: 0.04443, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9990/10000], Step [0/1], Loss: 0.04443, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9991/10000], Step [0/1], Loss: 0.04443, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9992/10000], Step [0/1], Loss: 0.04442, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9993/10000], Step [0/1], Loss: 0.04442, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9994/10000], Step [0/1], Loss: 0.04442, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9995/10000], Step [0/1], Loss: 0.04441, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9996/10000], Step [0/1], Loss: 0.04441, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9997/10000], Step [0/1], Loss: 0.04441, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9998/10000], Step [0/1], Loss: 0.04441, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [9999/10000], Step [0/1], Loss: 0.04440, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Epoch [10000/10000], Step [0/1], Loss: 0.04440, Train_Acc:99.78%
# Accuary on test images:99.78%, loss:0.04
# Best accuracy is: 99.78%, Minimum loss is: 0.0444
