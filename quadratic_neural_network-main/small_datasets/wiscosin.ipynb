# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import torch.backends.cudnn as cudnn
from tensorboardX import SummaryWriter
import model.simplenet as simplenet
import matplotlib.pyplot as plt
import torch.utils.data as Data
import imageio
import numpy as np
import random
import pandas as pd

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.enabled = False
    torch.backends.cudnn.benchmark = False
    #torch.backends.cudnn.benchmark = True #for accelerating the running
    return

def savefig(name):
    plt.savefig(name,dpi=600, bbox_inches='tight')
    return

def change_weight(weight):
    '''
    Change the weight matrix in quadratic neural network.
    '''
    model_dict = model.state_dict()
    model_dict['classifier.0.weight_a'] = weight
    model.load_state_dict(model_dict)
    
    return

from sklearn.datasets import load_breast_cancer


breast_cancer = load_breast_cancer()['data']
for i in range(breast_cancer.shape[1]):
    breast_cancer[:,i] = breast_cancer[:,i]/max(breast_cancer[:,i])

target = torch.from_numpy(load_breast_cancer()['target'])

device = torch.device('cpu')
writer = SummaryWriter()

train_dataset = torch.from_numpy(breast_cancer)
valid_dataset = torch.from_numpy(breast_cancer)

EI_distribution = torch.bernoulli(torch.ones(30)*0.75)
print('number of excitatory neuron:{}'.format(EI_distribution.sum()))
kappa_matrix = -torch.ones(30, 30)
kappa_matrix[EI_distribution==0,:] = 1
kappa_matrix[:,EI_distribution==0] = 1

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=569, shuffle=False)
valid_loader = torch.utils.data.DataLoader(dataset=valid_dataset, batch_size=569)


model = simplenet.SimpleNet_0(num_eigens=1, EI_distribution=EI_distribution)

print(model)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)
test_accuracy = []
train_accuracy = [0]
all_train_loss = []
image_list = []
best_prec = 0
min_loss = 1

for epoch in range(0, 10000):

    for param_group in optimizer.param_groups:
        param_group['lr'] = 0.01

    model.train()
    # train for one epoch
    for i, input in enumerate(train_loader):
        train_total = 0
        train_correct = 0
        train_loss = 0
                    
        
        # compute output
        output = model(input.to(torch.float32))
        loss = criterion(output, target)

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward() 
        optimizer.step()

        weight_a = model.state_dict()['classifier.0.weight_a']
        new_weight = weight_a.data
        for j in range(2):
            new_weight[j,(new_weight[j,:,:]*kappa_matrix)<0] = 0

        change_weight(new_weight)  

        _, predicted = torch.max(output.data, 1)
        train_total = target.size(0)
        train_correct = (predicted == target).sum().item()
        prec = train_correct / train_total

        if (i) % 300 == 0:
            train_accuracy.append(prec)
            all_train_loss.append(loss)

            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.5f}, Train_Acc:{:.2f}%'.format(epoch+1, 10000, i, len(train_loader), loss, prec*100))

    
            model.eval()
            valid_correct = 0
            valid_total = 0
            with torch.no_grad():
                total_loss = 0
                for j, input in enumerate(valid_loader):
                    output = model(input.to(torch.float32))
                    
                    _, predicted = torch.max(output.data, 1)
                    valid_total = output.shape[0]
                    valid_correct = (predicted == target).sum().item()
                    loss = criterion(output, target)
                
                    prec = valid_correct / valid_total
                    print('Accuary on test images:{:.2f}%, loss:{:.2f}'.format(prec*100, loss))
                    test_accuracy.append(prec)
                    best_prec = max(prec, best_prec)
                    min_loss = min(min_loss, loss)
        
print('Best accuracy is: {:.2f}%, Minimum loss is: {:.4f}'.format(best_prec*100, min_loss))
# Out:
# number of excitatory neuron:24.0
# SimpleNet_0(
#   (classifier): Sequential(
#     (0): Dales_General_quadratic(in_features=30, out_features=2, bias=False)
#   )
# )
# Epoch [1/10000], Step [0/1], Loss: 0.77140, Train_Acc:25.31%
# Accuary on test images:24.25%, loss:0.76
# Epoch [2/10000], Step [0/1], Loss: 0.76485, Train_Acc:24.25%
# Accuary on test images:22.50%, loss:0.76
# Epoch [3/10000], Step [0/1], Loss: 0.75880, Train_Acc:22.50%
# Accuary on test images:21.27%, loss:0.75
# Epoch [4/10000], Step [0/1], Loss: 0.75312, Train_Acc:21.27%
# Accuary on test images:22.32%, loss:0.75
# Epoch [5/10000], Step [0/1], Loss: 0.74776, Train_Acc:22.32%
# Accuary on test images:21.27%, loss:0.74
# Epoch [6/10000], Step [0/1], Loss: 0.74268, Train_Acc:21.27%
# Accuary on test images:21.62%, loss:0.74
# Epoch [7/10000], Step [0/1], Loss: 0.73784, Train_Acc:21.62%
# Accuary on test images:21.97%, loss:0.73
# Epoch [8/10000], Step [0/1], Loss: 0.73319, Train_Acc:21.97%
# Accuary on test images:23.55%, loss:0.73
# Epoch [9/10000], Step [0/1], Loss: 0.72871, Train_Acc:23.55%
# Accuary on test images:25.48%, loss:0.72
# Epoch [10/10000], Step [0/1], Loss: 0.72437, Train_Acc:25.48%
# Accuary on test images:26.71%, loss:0.72
# Epoch [11/10000], Step [0/1], Loss: 0.72015, Train_Acc:26.71%
# Accuary on test images:28.47%, loss:0.72
# Epoch [12/10000], Step [0/1], Loss: 0.71604, Train_Acc:28.47%
# Accuary on test images:29.88%, loss:0.71
# Epoch [13/10000], Step [0/1], Loss: 0.71202, Train_Acc:29.88%
# Accuary on test images:32.51%, loss:0.71
# Epoch [14/10000], Step [0/1], Loss: 0.70809, Train_Acc:32.51%
# Accuary on test images:34.45%, loss:0.70
# Epoch [15/10000], Step [0/1], Loss: 0.70423, Train_Acc:34.45%
# Accuary on test images:36.20%, loss:0.70
# Epoch [16/10000], Step [0/1], Loss: 0.70045, Train_Acc:36.20%
# Accuary on test images:39.89%, loss:0.70
# Epoch [17/10000], Step [0/1], Loss: 0.69674, Train_Acc:39.89%
# Accuary on test images:41.12%, loss:0.69
# Epoch [18/10000], Step [0/1], Loss: 0.69310, Train_Acc:41.12%
# Accuary on test images:42.88%, loss:0.69
# Epoch [19/10000], Step [0/1], Loss: 0.68951, Train_Acc:42.88%
# Accuary on test images:45.69%, loss:0.69
# Epoch [20/10000], Step [0/1], Loss: 0.68598, Train_Acc:45.69%
# Accuary on test images:47.98%, loss:0.68
# Epoch [21/10000], Step [0/1], Loss: 0.68250, Train_Acc:47.98%
# Accuary on test images:51.32%, loss:0.68
# Epoch [22/10000], Step [0/1], Loss: 0.67907, Train_Acc:51.32%
# Accuary on test images:54.31%, loss:0.68
# Epoch [23/10000], Step [0/1], Loss: 0.67569, Train_Acc:54.31%
# Accuary on test images:58.00%, loss:0.67
# Epoch [24/10000], Step [0/1], Loss: 0.67236, Train_Acc:58.00%
# Accuary on test images:60.98%, loss:0.67
# Epoch [25/10000], Step [0/1], Loss: 0.66907, Train_Acc:60.98%
# Accuary on test images:66.26%, loss:0.67
# Epoch [26/10000], Step [0/1], Loss: 0.66582, Train_Acc:66.26%
# Accuary on test images:68.19%, loss:0.66
# Epoch [27/10000], Step [0/1], Loss: 0.66262, Train_Acc:68.19%
# Accuary on test images:69.95%, loss:0.66
# Epoch [28/10000], Step [0/1], Loss: 0.65945, Train_Acc:69.95%
# Accuary on test images:73.29%, loss:0.66
# Epoch [29/10000], Step [0/1], Loss: 0.65633, Train_Acc:73.29%
# Accuary on test images:75.75%, loss:0.65
# Epoch [30/10000], Step [0/1], Loss: 0.65324, Train_Acc:75.75%
# Accuary on test images:78.56%, loss:0.65
# Epoch [31/10000], Step [0/1], Loss: 0.65019, Train_Acc:78.56%
# Accuary on test images:79.96%, loss:0.65
# Epoch [32/10000], Step [0/1], Loss: 0.64718, Train_Acc:79.96%
# Accuary on test images:80.84%, loss:0.64
# Epoch [33/10000], Step [0/1], Loss: 0.64421, Train_Acc:80.84%
# Accuary on test images:82.43%, loss:0.64
# Epoch [34/10000], Step [0/1], Loss: 0.64127, Train_Acc:82.43%
# Accuary on test images:83.83%, loss:0.64
# Epoch [35/10000], Step [0/1], Loss: 0.63837, Train_Acc:83.83%
# Accuary on test images:84.36%, loss:0.64
# Epoch [36/10000], Step [0/1], Loss: 0.63550, Train_Acc:84.36%
# Accuary on test images:85.59%, loss:0.63
# Epoch [37/10000], Step [0/1], Loss: 0.63267, Train_Acc:85.59%
# Accuary on test images:85.94%, loss:0.63
# Epoch [38/10000], Step [0/1], Loss: 0.62987, Train_Acc:85.94%
# Accuary on test images:85.94%, loss:0.63
# Epoch [39/10000], Step [0/1], Loss: 0.62711, Train_Acc:85.94%
# Accuary on test images:86.47%, loss:0.62
# Epoch [40/10000], Step [0/1], Loss: 0.62439, Train_Acc:86.47%
# Accuary on test images:87.17%, loss:0.62
# Epoch [41/10000], Step [0/1], Loss: 0.62171, Train_Acc:87.17%
# Accuary on test images:88.05%, loss:0.62
# Epoch [42/10000], Step [0/1], Loss: 0.61907, Train_Acc:88.05%
# Accuary on test images:88.40%, loss:0.62
# Epoch [43/10000], Step [0/1], Loss: 0.61646, Train_Acc:88.40%
# Accuary on test images:88.75%, loss:0.61
# Epoch [44/10000], Step [0/1], Loss: 0.61388, Train_Acc:88.75%
# Accuary on test images:88.93%, loss:0.61
# Epoch [45/10000], Step [0/1], Loss: 0.61133, Train_Acc:88.93%
# Accuary on test images:89.28%, loss:0.61
# Epoch [46/10000], Step [0/1], Loss: 0.60881, Train_Acc:89.28%
# Accuary on test images:89.63%, loss:0.61
# Epoch [47/10000], Step [0/1], Loss: 0.60632, Train_Acc:89.63%
# Accuary on test images:89.98%, loss:0.60
# Epoch [48/10000], Step [0/1], Loss: 0.60385, Train_Acc:89.98%
# Accuary on test images:90.16%, loss:0.60
# Epoch [49/10000], Step [0/1], Loss: 0.60142, Train_Acc:90.16%
# Accuary on test images:90.16%, loss:0.60
# Epoch [50/10000], Step [0/1], Loss: 0.59902, Train_Acc:90.16%
# Accuary on test images:90.16%, loss:0.60
# Epoch [51/10000], Step [0/1], Loss: 0.59664, Train_Acc:90.16%
# Accuary on test images:89.98%, loss:0.59
# Epoch [52/10000], Step [0/1], Loss: 0.59429, Train_Acc:89.98%
# Accuary on test images:89.98%, loss:0.59
# Epoch [53/10000], Step [0/1], Loss: 0.59196, Train_Acc:89.98%
# Accuary on test images:90.33%, loss:0.59
# Epoch [54/10000], Step [0/1], Loss: 0.58966, Train_Acc:90.33%
# Accuary on test images:90.16%, loss:0.59
# Epoch [55/10000], Step [0/1], Loss: 0.58738, Train_Acc:90.16%
# Accuary on test images:90.33%, loss:0.59
# Epoch [56/10000], Step [0/1], Loss: 0.58513, Train_Acc:90.33%
# Accuary on test images:90.33%, loss:0.58
# Epoch [57/10000], Step [0/1], Loss: 0.58291, Train_Acc:90.33%
# Accuary on test images:90.51%, loss:0.58
# Epoch [58/10000], Step [0/1], Loss: 0.58070, Train_Acc:90.51%
# Accuary on test images:90.51%, loss:0.58
# Epoch [59/10000], Step [0/1], Loss: 0.57852, Train_Acc:90.51%
# Accuary on test images:90.69%, loss:0.58
# Epoch [60/10000], Step [0/1], Loss: 0.57637, Train_Acc:90.69%
# Accuary on test images:91.04%, loss:0.57
# Epoch [61/10000], Step [0/1], Loss: 0.57424, Train_Acc:91.04%
# Accuary on test images:91.04%, loss:0.57
# Epoch [62/10000], Step [0/1], Loss: 0.57213, Train_Acc:91.04%
# Accuary on test images:91.04%, loss:0.57
# Epoch [63/10000], Step [0/1], Loss: 0.57005, Train_Acc:91.04%
# Accuary on test images:91.04%, loss:0.57
# Epoch [64/10000], Step [0/1], Loss: 0.56799, Train_Acc:91.04%
# Accuary on test images:91.04%, loss:0.57
# Epoch [65/10000], Step [0/1], Loss: 0.56594, Train_Acc:91.04%
# Accuary on test images:91.04%, loss:0.56
# Epoch [66/10000], Step [0/1], Loss: 0.56393, Train_Acc:91.04%
# Accuary on test images:90.86%, loss:0.56
# Epoch [67/10000], Step [0/1], Loss: 0.56194, Train_Acc:90.86%
# Accuary on test images:90.69%, loss:0.56
# Epoch [68/10000], Step [0/1], Loss: 0.55997, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.56
# Epoch [69/10000], Step [0/1], Loss: 0.55801, Train_Acc:90.69%
# Accuary on test images:90.86%, loss:0.56
# Epoch [70/10000], Step [0/1], Loss: 0.55608, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.55
# Epoch [71/10000], Step [0/1], Loss: 0.55417, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.55
# Epoch [72/10000], Step [0/1], Loss: 0.55227, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.55
# Epoch [73/10000], Step [0/1], Loss: 0.55040, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.55
# Epoch [74/10000], Step [0/1], Loss: 0.54855, Train_Acc:90.86%
# Accuary on test images:90.69%, loss:0.55
# Epoch [75/10000], Step [0/1], Loss: 0.54671, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.54
# Epoch [76/10000], Step [0/1], Loss: 0.54489, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.54
# Epoch [77/10000], Step [0/1], Loss: 0.54310, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.54
# Epoch [78/10000], Step [0/1], Loss: 0.54132, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.54
# Epoch [79/10000], Step [0/1], Loss: 0.53958, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.54
# Epoch [80/10000], Step [0/1], Loss: 0.53787, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.54
# Epoch [81/10000], Step [0/1], Loss: 0.53616, Train_Acc:90.69%
# Accuary on test images:91.04%, loss:0.53
# Epoch [82/10000], Step [0/1], Loss: 0.53448, Train_Acc:91.04%
# Accuary on test images:90.69%, loss:0.53
# Epoch [83/10000], Step [0/1], Loss: 0.53281, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.53
# Epoch [84/10000], Step [0/1], Loss: 0.53115, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.53
# Epoch [85/10000], Step [0/1], Loss: 0.52951, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.53
# Epoch [86/10000], Step [0/1], Loss: 0.52789, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.53
# Epoch [87/10000], Step [0/1], Loss: 0.52628, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.52
# Epoch [88/10000], Step [0/1], Loss: 0.52469, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.52
# Epoch [89/10000], Step [0/1], Loss: 0.52312, Train_Acc:90.69%
# Accuary on test images:90.86%, loss:0.52
# Epoch [90/10000], Step [0/1], Loss: 0.52156, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.52
# Epoch [91/10000], Step [0/1], Loss: 0.52001, Train_Acc:90.86%
# Accuary on test images:91.04%, loss:0.52
# Epoch [92/10000], Step [0/1], Loss: 0.51848, Train_Acc:91.04%
# Accuary on test images:91.04%, loss:0.52
# Epoch [93/10000], Step [0/1], Loss: 0.51697, Train_Acc:91.04%
# Accuary on test images:91.04%, loss:0.52
# Epoch [94/10000], Step [0/1], Loss: 0.51546, Train_Acc:91.04%
# Accuary on test images:90.86%, loss:0.51
# Epoch [95/10000], Step [0/1], Loss: 0.51398, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.51
# Epoch [96/10000], Step [0/1], Loss: 0.51250, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.51
# Epoch [97/10000], Step [0/1], Loss: 0.51104, Train_Acc:90.86%
# Accuary on test images:91.04%, loss:0.51
# Epoch [98/10000], Step [0/1], Loss: 0.50959, Train_Acc:91.04%
# Accuary on test images:91.04%, loss:0.51
# Epoch [99/10000], Step [0/1], Loss: 0.50816, Train_Acc:91.04%
# Accuary on test images:91.04%, loss:0.51
# Epoch [100/10000], Step [0/1], Loss: 0.50674, Train_Acc:91.04%
# Accuary on test images:90.86%, loss:0.51
# Epoch [101/10000], Step [0/1], Loss: 0.50533, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.50
# Epoch [102/10000], Step [0/1], Loss: 0.50393, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.50
# Epoch [103/10000], Step [0/1], Loss: 0.50254, Train_Acc:90.86%
# Accuary on test images:90.69%, loss:0.50
# Epoch [104/10000], Step [0/1], Loss: 0.50118, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.50
# Epoch [105/10000], Step [0/1], Loss: 0.49982, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.50
# Epoch [106/10000], Step [0/1], Loss: 0.49848, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.50
# Epoch [107/10000], Step [0/1], Loss: 0.49715, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.50
# Epoch [108/10000], Step [0/1], Loss: 0.49582, Train_Acc:90.69%
# Accuary on test images:90.51%, loss:0.49
# Epoch [109/10000], Step [0/1], Loss: 0.49451, Train_Acc:90.51%
# Accuary on test images:90.51%, loss:0.49
# Epoch [110/10000], Step [0/1], Loss: 0.49321, Train_Acc:90.51%
# Accuary on test images:90.51%, loss:0.49
# Epoch [111/10000], Step [0/1], Loss: 0.49192, Train_Acc:90.51%
# Accuary on test images:90.51%, loss:0.49
# Epoch [112/10000], Step [0/1], Loss: 0.49065, Train_Acc:90.51%
# Accuary on test images:90.51%, loss:0.49
# Epoch [113/10000], Step [0/1], Loss: 0.48938, Train_Acc:90.51%
# Accuary on test images:90.51%, loss:0.49
# Epoch [114/10000], Step [0/1], Loss: 0.48812, Train_Acc:90.51%
# Accuary on test images:90.51%, loss:0.49
# Epoch [115/10000], Step [0/1], Loss: 0.48688, Train_Acc:90.51%
# Accuary on test images:90.51%, loss:0.49
# Epoch [116/10000], Step [0/1], Loss: 0.48564, Train_Acc:90.51%
# Accuary on test images:90.69%, loss:0.48
# Epoch [117/10000], Step [0/1], Loss: 0.48442, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.48
# Epoch [118/10000], Step [0/1], Loss: 0.48321, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.48
# Epoch [119/10000], Step [0/1], Loss: 0.48201, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.48
# Epoch [120/10000], Step [0/1], Loss: 0.48082, Train_Acc:90.69%
# Accuary on test images:90.51%, loss:0.48
# Epoch [121/10000], Step [0/1], Loss: 0.47965, Train_Acc:90.51%
# Accuary on test images:90.51%, loss:0
Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.43
# Epoch [168/10000], Step [0/1], Loss: 0.43357, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.43
# Epoch [169/10000], Step [0/1], Loss: 0.43275, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.43
# Epoch [170/10000], Step [0/1], Loss: 0.43195, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.43
# Epoch [171/10000], Step [0/1], Loss: 0.43115, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.43
# Epoch [172/10000], Step [0/1], Loss: 0.43036, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.43
# Epoch [173/10000], Step [0/1], Loss: 0.42957, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.43
# Epoch [174/10000], Step [0/1], Loss: 0.42879, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.43
# Epoch [175/10000], Step [0/1], Loss: 0.42801, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.43
# Epoch [176/10000], Step [0/1], Loss: 0.42724, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.43
# Epoch [177/10000], Step [0/1], Loss: 0.42648, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.43
# Epoch [178/10000], Step [0/1], Loss: 0.42571, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.42
# Epoch [179/10000], Step [0/1], Loss: 0.42496, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.42
# Epoch [180/10000], Step [0/1], Loss: 0.42420, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.42
# Epoch [181/10000], Step [0/1], Loss: 0.42346, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.42
# Epoch [182/10000], Step [0/1], Loss: 0.42271, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.42
# Epoch [183/10000], Step [0/1], Loss: 0.42198, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.42
# Epoch [184/10000], Step [0/1], Loss: 0.42124, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.42
# Epoch [185/10000], Step [0/1], Loss: 0.42051, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.42
# Epoch [186/10000], Step [0/1], Loss: 0.41979, Train_Acc:90.69%
# Accuary on test images:90.69%, loss:0.42
# Epoch [187/10000], Step [0/1], Loss: 0.41907, Train_Acc:90.69%
# Accuary on test images:90.51%, loss:0.42
# Epoch [188/10000], Step [0/1], Loss: 0.41835, Train_Acc:90.51%
# Accuary on test images:90.51%, loss:0.42
# Epoch [189/10000], Step [0/1], Loss: 0.41764, Train_Acc:90.51%
# Accuary on test images:90.51%, loss:0.42
# Epoch [190/10000], Step [0/1], Loss: 0.41693, Train_Acc:90.51%
# Accuary on test images:90.51%, loss:0.42
# Epoch [191/10000], Step [0/1], Loss: 0.41622, Train_Acc:90.51%
# Accuary on test images:90.69%, loss:0.42
# Epoch [192/10000], Step [0/1], Loss: 0.41553, Train_Acc:90.69%
# Accuary on test images:90.86%, loss:0.41
# Epoch [193/10000], Step [0/1], Loss: 0.41485, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.41
# Epoch [194/10000], Step [0/1], Loss: 0.41417, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.41
# Epoch [195/10000], Step [0/1], Loss: 0.41349, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.41
# Epoch [196/10000], Step [0/1], Loss: 0.41281, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.41
# Epoch [197/10000], Step [0/1], Loss: 0.41215, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.41
# Epoch [198/10000], Step [0/1], Loss: 0.41148, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.41
# Epoch [199/10000], Step [0/1], Loss: 0.41082, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.41
# Epoch [200/10000], Step [0/1], Loss: 0.41016, Train_Acc:90.86%
# Accuary on test images:90.86%, loss:0.41
# Epoch [201/10000], Step [0/1], Loss: 0.40950, Train_Acc:90.86%
# Accuary on test images:91.04%, loss:0.41
# Epoch [202/10000], Step [0/1], Loss: 0.40885, Train_Acc:91.04%
# Accuary on test images:91.04%, loss:0.41
# Epoch [203/10000], Step [0/1], Loss: 0.40820, Train_Acc:91.04%
# Accuary on test images:91.21%, loss:0.41
# Epoch [204/10000], Step [0/1], Loss: 0.40756, Train_Acc:91.21%
# Accuary on test images:91.21%, loss:0.41
# Epoch [205/10000], Step [0/1], Loss: 0.40692, Train_Acc:91.21%
# Accuary on test images:91.21%, loss:0.41
# Epoch [206/10000], Step [0/1], Loss: 0.40628, Train_Acc:91.21%
# Accuary on test images:91.21%, loss:0.41
# Epoch [207/10000], Step [0/1], Loss: 0.40565, Train_Acc:91.21%
# Accuary on test images:91.21%, loss:0.41
# Epoch [208/10000], Step [0/1], Loss: 0.40502, Train_Acc:91.21%
# Accuary on test images:91.21%, loss:0.40
# Epoch